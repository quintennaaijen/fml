# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt #Useful to include matplotlib when plotting with Seaborn, because Seaborn is built on it.

# %%
df = pd.read_csv('assignment2.csv')
df.head()
# Out:
#    Unnamed: 0                         address  area  bedrooms postal_code  \
# 0           0       Knollendamstraat 4 III/IV   108         2     1013 TN
# 1           1             Moerdijkstraat 47 1    47         1     1079 XM
# 2           2               Zeeburgerdijk 349   116         2     1095 AD
# 3           3          Brederodestraat 124 -1    58         2     1054 VH
# 4           4  Admiraal De Ruijterweg 409 III    63         1     1055 MD
#
#   posting_date   price property_type  rooms  sale_date  \
# 0     4-6-2016  510000     apartment      3  23-6-2016
# 1    22-6-2016  215000     apartment      2   5-7-2016
# 2     9-6-2016  325000     apartment      3   8-7-2016
# 3    14-5-2016  315000     apartment      3   2-6-2016
# 4    14-6-2016  200000     apartment      3  23-6-2016
#
#                                                  url  year_built
# 0  http://www.funda.nl/koop/verkocht/amsterdam/ap...        1906
# ...

# %%
sns.pairplot(df)
plt.show()

# %%
df['area_m'] = df['area'] 
df['price_m'] = df['price']  

sns.lmplot(x='area_m', y='price_m', fit_reg=False, data=df) #fit_reg=False leaves out the regression line; see below
plt.xlabel('area') #use matplotlib to refine Seaborn plot
plt.ylabel('price')
plt.title('funda amsterdam price/area')
plt.show()

# %%
df['bedrooms_m'] = df['bedrooms'] 
df['price_m'] = df[df['price']>10000] 

sns.lmplot(x='bedrooms_m', y='price_m', fit_reg=False, data=df) #fit_reg=False leaves out the regression line; see below
plt.xlabel('bedrooms') #use matplotlib to refine Seaborn plot
plt.ylabel('price')
plt.title('funda amsterdam price/bedrooms')
plt.show()

# %%
from scipy.stats.stats import pearsonr #We will need the correlation function from the scientific package scipy
print(pearsonr(df['price'],df['area']))
print(pearsonr(df['price'],df['bedrooms']))
# Out:
# (0.31248795026382037, 1.2701622617660068e-257)
# (0.28791785559228794, 2.670965859578847e-217)
