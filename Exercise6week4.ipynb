# %% [markdown]
# # Exercise6week4 Linear regression recap

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import math
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

# %%
df = pd.read_csv('bol_sales.csv')
df.head()
# Out:
#          id  gender  income  distance_center  website_visits  pages_viewed  \
# 0  person_1  female    7065              4.6              30           105
# 1  person_2  female   23028              9.8              23            81
# 2  person_3  female  103377              9.2              11            38
# 3  person_4  female    9815              3.2              16            54
# 4  person_5  female   22646             10.1              21            78
#
#    time_social_media  spent_bol
# 0                117       1232
# 1                 70       1396
# 2                 94       1240
# 3                124        720
# 4                119       1379

# %%
sns.pairplot(df)
plt.show()

# %%
df.corr()
# Out:
#                      income  distance_center  website_visits  pages_viewed  \
# income             1.000000         0.298612       -0.085088     -0.095738
# distance_center    0.298612         1.000000        0.006597     -0.016633
# website_visits    -0.085088         0.006597        1.000000      0.983754
# pages_viewed      -0.095738        -0.016633        0.983754      1.000000
# time_social_media -0.065139         0.093626       -0.035425     -0.000302
# spent_bol          0.565621         0.392954        0.677874      0.682696
#
#                    time_social_media  spent_bol
# income                     -0.065139   0.565621
# distance_center             0.093626   0.392954
# website_visits             -0.035425   0.677874
# pages_viewed               -0.000302   0.682696
# time_social_media           1.000000   0.034558
# spent_bol                   0.034558   1.000000

# %%
sns.lmplot(x='income', y='spent_bol', fit_reg=False, data=df) #fit_reg=False leaves out the regression line; see below
plt.xlabel('income')
plt.ylabel('spent on bol')
plt.title('Spent and income')
plt.show()

# %%
sns.lmplot(x='income', y='spent_bol', data=df, ci=False) #The last argument leaves out a so-called "confidence interval"
plt.xlabel('Income')
plt.ylabel('spent on bol')
plt.title('Spent and income')
plt.show()

# %% [markdown]
# I was not my morning.. --> assignment 3 week3 more
